# %% [markdown]
# <a href="https://colab.research.google.com/github/javohuz/Data_Science_and_AI/blob/main/Data_Storage_Files/%2301_Files_json_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fayllar bilan ishlash
#
# `pandas` kutubxonasi fayllar bilan ishlaydigan bir nechta funksiyalardan iborat.
#
# `read_csv` - vergul bilan ajratilgan jadval fayllarni o'qish uchun
#
# `read_table` - probel (bo'sh joy) bilan ajratilgan jadval fayllarni o'qish uchun
#
# `read_excel` - `xls` yoki `xlsx` formatidagi **Excel** fayllarni o'qish uchun
#
# `read_clipboard` - ko'chirilgan (xotiradagi) jadvalni o'qish
#
# `read_hdf` - `HDF5` formatidagi fayllarni o'qish
#
# `read_html` - HTML (web) sahifadagi barcha jadvallarni o'qish
#
# `read_json` - `JSON` ma'lumotlarni o'qish
#
# `read_pickle` - pickle formatidagi fayllarni o'qish
#
# `read_sql` - SQL query dan qaytgan ma'lumotlarni o'qish (SQLAlchemy bilan ishlayd)

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv
# Datani yuklab aladi
# Out:
# --2024-01-29 19:15:09--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 279432 (273K) [text/plain]
# Saving to: ‘usa_cars.csv’
#
# usa_cars.csv        100%[===================>] 272.88K  --.-KB/s    in 0.03s
#
# 2024-01-29 19:15:10 (8.32 MB/s) - ‘usa_cars.csv’ saved [279432/279432]

# %%
# !git clone  https://github.com/anvarnarz/praktikum_datasets
# git dan repoxetoriyani yuklab olish
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv")
# malumotni yuklab olmasdan tugridan tug'ri ochish
# Out:
#       Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1              1   2899       ford       se  2011  clean vehicle   190552
# 2              2   5350      dodge      mpv  2018  clean vehicle    39590
# 3              3  25000       ford     door  2014  clean vehicle    64146
# 4              4  27700  chevrolet     1500  2018  clean vehicle     6654
# ...          ...    ...        ...      ...   ...            ...      ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle    23609
# 2495        2495   9200     nissan    versa  2018  clean vehicle    34553
# 2496        2496   9200     nissan    versa  2018  clean vehicle    31594
# 2497        2497   9200     nissan    versa  2018  clean vehicle    32557
# 2498        2498   9200     nissan    versa  2018  clean vehicle    31371
#
#        color                  vin        lot       state country  \
# ...

# %%
pd.read_csv('praktikum_datasets/MOCK_USER_DATA.csv' , index_col=0 , names= ['first_name', 	'last_name', 'email', 	'gender', 	'age'])
# index_col=0 indexni uzgartish
# names=[list] columnslaga nom berish or uzgartish
# Out:
#      first_name   last_name                           email       gender   age
# id   first_name   last_name                           email       gender   age
# 1       Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2       Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3        Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4          Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# ..          ...         ...                             ...          ...   ...
# 96         Baxy       Marcu        bmarcu2n@list-manage.com      Agender    64
# 97       Kattie     Claxson          kclaxson2o@booking.com       Female    18
# 98         Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender    55
# 99    Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid    46
# 100       Mable     Toffano          mtoffano2r@myspace.com     Bigender   233
#
# [101 rows x 5 columns]

# %%
pd.read_excel('KURS ISHI 3.xlsx' , names= list(range(1,14)) , nrows= 15)
# nrwos boshidan 20 ta elementni uqiydi
# Out:
#                    1           2           3           4           5   \
# S                   0    0.022000    0.100000    0.200000    0.300000
# S/SK                0    0.271605    1.234568    2.469136    3.703704
# SK/S                0    3.681818    0.810000    0.405000    0.270000
# SK/S+S/SK           0    3.953423    2.044568    2.874136    3.973704
# Mmot                0  109.272392  211.291589  150.306050  108.714698
# Mmot-Mc           -18   91.272392  193.291589  132.306050   90.714698
# n1               1000  978.000000  900.000000  800.000000  700.000000
# NaN               NaN         NaN         NaN         NaN         NaN
# NaN               NaN         NaN         NaN         NaN         NaN
# NaN               NaN         NaN         NaN         NaN         NaN
# NaN               NaN         NaN         NaN         NaN         NaN
# NaN               NaN         NaN         NaN         NaN         NaN
# ...

# %% [markdown]
# # Faylga yozish (to_)
#  - `DF.to_format(file)` Fillarni yuklab ishlov bergandan keyin kerakli faylni yoki kerakli qatorlarin uzimiz hohlagan shaklada yuklab olishimiz mumkun

# %%
df1 = pd.read_excel('KURS ISHI 3.xlsx' , names= list(range(1,14)) , nrows= 7)
df1.to_excel('KURS_ish.xlsx' , index=False) # index = False indexsiz saqaliydi yani birinchi qator indexlarini

# %%
df1.to_csv('demo.csv' , columns=[1,2,3])
pd.read_csv('demo.csv' , index_col=0)
# Out:
#             1     2           3
# 0           S     0    0.022000
# 1        S/SK     0    0.271605
# 2        SK/S     0    3.681818
# 3  SK/S+S/SK      0    3.953423
# 4        Mmot     0  109.272392
# 5     Mmot-Mc   -18   91.272392
# 6          n1  1000  978.000000

# %% [markdown]
# ### `HDF5` formati.
# HDF5 formati ilmiy tadqiqodlar qilishda katta hajmdagi ma'lumotlarni saqlash uchun keng ioshlatiladigan formatlardan hisoblanadi.
#
# HDF5 fayllarni nafaqat Python, balki Java, Julia, Matlab va boshqa dasturlash tillarida ochish mumkin.
#
# HDF - __hierarchial data format__ (irarxiyali ma'lumotlar formati) hisoblanib, tarkibida bir nechta datasetlarni siqilgan holatda saqlashi mumkin.
#
# HDF formatida fayllarni saqlash uchun avval HDF obyketini yaratamiz:

# %%
data = pd.HDFStore('HDFfile')
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: HDFfile

# %%
df2 = df1 # ikkida dataframe

# %% [markdown]
# malumot qushamiz

# %%
data['data1'] = df1
data['data2'] = df2

# %%
data['data2'] # hullas bitta file ichiga bir nechda dataframelarni saqalash
# Out:
#            1     2           3           4           5           6   \
# 0           S     0    0.022000    0.100000    0.200000    0.300000
# 1        S/SK     0    0.271605    1.234568    2.469136    3.703704
# 2        SK/S     0    3.681818    0.810000    0.405000    0.270000
# 3  SK/S+S/SK      0    3.953423    2.044568    2.874136    3.973704
# 4        Mmot     0  109.272392  211.291589  150.306050  108.714698
# 5     Mmot-Mc   -18   91.272392  193.291589  132.306050   90.714698
# 6          n1  1000  978.000000  900.000000  800.000000  700.000000
#
#            7           8           9           10          11          12  \
# 0    0.400000    0.500000    0.600000    0.700000    0.800000    0.900000
# 1    4.938272    6.172840    7.407407    8.641975    9.876543   11.111111
# 2    0.202500    0.162000    0.135000    0.115714    0.101250    0.090000
# 3    5.140772    6.334840    7.542407    8.757690    9.977793   11.201111
# ...

# %%
data.close() # ochiq turgan bulsa yopish

# %%
df1.to_hdf('data1' , key='data1') # bittada to orqali saqlab quyish

# %%
data =  pd.HDFStore('HDFfile') # yopilgan hdfni qayta ishga tushirish
data.keys()
# Out:
# ['/data1', '/data2']

# %% [markdown]
# Agar keys ni bilsan read_hdf bilanham olib ishlatsak buladi

# %%
data.close()

# %%
df = pd.read_hdf('HDFfile' , key='data1')
df

# %%
javo = pd.read_html('https://javo.uz/post/23/#p')

# %%
javo[0]
# Out:
#       0  1
# 0  demo  1
# 1  demo  2
# 2  demo  3

# %% [markdown]
# # Json va Api

# %%
import requests

# %%
r = requests.get('http://openlibrary.org/subjects/python.json?published_in=2020-2024')
r # Open books dan 2020 dan 2024 gacha chiqqan kitoblarni API orqali json kurinishida yuklab oldik
# bularni !wget orqali ham yuklab olsa buladi leikin u biz kutgan natijani betmasligi mumkun yani bizga kerakli infolar
# yuklab olgan jsonni malum bir ustini bulish mumkun requests bizga jsonni olib uning ichidagi bitta columnsni oilb uqshi ishlatidi hozir
# Out:
# <Response [200]>

# %%
pd.DataFrame(r.json()['works']) # yuklab olingan jsonni daraframe ga utqazish
# Out:
#                    key                                              title  \
# 0   /works/OL16976951W                                       Think Python
# 1   /works/OL15664278W                                  Head First Python
# 2    /works/OL6045694W                               Python in a Nutshell
# 3   /works/OL17422847W                           Python For Data Analysis
# 4   /works/OL21703042W                               Tour of Data Science
# 5   /works/OL19548251W                                Python for Everyone
# 6   /works/OL19932156W                                      Fluent Python
# 7   /works/OL25777002W                                Pandas for Everyone
# 8   /works/OL25347363W                      Survival Analysis with Python
# 9   /works/OL21245028W                                   Bite-Size Python
# 10  /works/OL17581315W                                        Think Bayes
# 11  /works/OL20115118W  Pygame - Initiez-vous au développement de jeux...
#
# ...

# %%
uz = requests.get('https://restcountries.com/v3.1/name/Uzbekistan?')
pd.DataFrame(uz.json()).T #REST Countries API info about uzbekistan
# Out:
#                                                               0
# name          {'common': 'Uzbekistan', 'official': 'Republic...
# tld                                                       [.uz]
# cca2                                                         UZ
# ccn3                                                        860
# cca3                                                        UZB
# cioc                                                        UZB
# independent                                                True
# status                                      officially-assigned
# unMember                                                   True
# currencies    {'UZS': {'name': 'Uzbekistani soʻm', 'symbol':...
# idd                          {'root': '+9', 'suffixes': ['98']}
# capital                                              [Tashkent]
# altSpellings  [UZ, Republic of Uzbekistan, O‘zbekiston Respu...
# region                                                     Asia
# ...
