# %% [markdown]
# <a href="https://colab.research.google.com/github/javohuz/Data_Science_and_AI/blob/main/NumPy/%2309_Math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matemetik va static ammalar
#
# ![statistics.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
arr = np.arange(6)
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# `sum` method

# %%
# sum yigindi
arr.sum()
# Out:
# 15

# %%
np.sum(arr)
# Out:
# 15

# %%
arr1 = np.random.randn(5,5)
arr1
# Out:
# array([[ 0.69671006,  0.36565399,  0.01552972, -0.14957408,  0.01768224],
#        [-0.41727329,  0.47453456,  1.14408609,  0.86113555, -0.12136451],
#        [-0.62835358, -0.04876436,  1.56841387, -1.07308949,  0.82907457],
#        [ 0.56478484,  0.32862528,  0.49463299, -1.05942803,  1.24966167],
#        [-1.00415069, -1.24998684, -0.0876442 ,  0.6301614 ,  0.82080507]])

# %%
np.sum(arr1)
# Out:
# 4.2218628318474325

# %%
# axis 0 ustun biyicha
# axis 1 qator buyicha
ustunSum = arr1.sum(axis=0)
qatorSum = arr1.sum(axis=1)
print(qatorSum , ustunSum )
ustun = np.sum(arr1, axis=0)
ustun
# Out:
# [ 0.94600192  1.94111839  0.64728103  1.57827675 -0.89081525] [-0.78828266 -0.12993737  3.13501847 -0.79079465  2.79585904]
# array([-0.78828266, -0.12993737,  3.13501847, -0.79079465,  2.79585904])

# %% [markdown]
# `mean` method o'rta arifmetik = > `sum(arr) / len(arr) `

# %%
orta = arr.sum()/len(arr)
orta
# Out:
# 2.5

# %%
mean = np.mean(arr)
mean
# Out:
# 2.5

# %%
mean = arr.mean()
mean
# Out:
# 2.5

# %% [markdown]
# - qatorlar yoki ustunlarning urta arifmetigi

# %%
mean1 = arr1.mean(axis=0)
mean1
# Out:
# array([-0.15765653, -0.02598747,  0.62700369, -0.15815893,  0.55917181])

# %%
mean01 = np.mean(arr1 , axis=0)
mean01
# Out:
# array([-0.15765653, -0.02598747,  0.62700369, -0.15815893,  0.55917181])

# %% [markdown]
# - `cumsum`  yigindinign yigindisi yani listdagi biron argumentiga bulgan argumentlar yigindisi ,

# %%
cumsum = arr.cumsum()
cumsum
# Out:
# array([ 0,  1,  3,  6, 10, 15])

# %%
max = arr.max()
max = np.max(arr)
max
# Out:
# 5
